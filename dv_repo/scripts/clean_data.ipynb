# %%
import pandas as pd

from pathlib import Path

# %%
# Load the dataset
scr_path = Path("../data/raw/vispubdata_1990_2024.csv")
df = pd.read_csv(scr_path)

# %%
df.shape
# Out:
# (3877, 20)

# %%
print(df.columns.tolist())
# Out:
# ['Conference', 'Year', 'Title', 'DOI', 'Link', 'FirstPage', 'LastPage', 'PaperType', 'Abstract', 'AuthorNames-Deduped', 'AuthorNames', 'AuthorAffiliation', 'InternalReferences', 'AuthorKeywords', 'AminerCitationCount', 'CitationCount_CrossRef', 'PubsCited_CrossRef', 'Downloads_Xplore', 'Award', 'GraphicsReplicabilityStamp']

# %%
cols_to_drop = ["Link", "FirstPage", "LastPage","AuthorNames","GraphicsReplicabilityStamp" ]
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns], errors="ignore")

if "PaperType" in df.columns:
    df = df[df["PaperType"].astype(str).str.strip().str.upper().ne("M")]

df["Abstract"] = df["Abstract"].astype(str)
df = df[df["Abstract"].str.strip().ne("") & df["Abstract"].ne("nan")]

df["AuthorNames-Deduped"] = df["AuthorNames-Deduped"].astype(str)
df = df[df["AuthorNames-Deduped"].str.strip().ne("") & df["AuthorNames-Deduped"].ne("nan")]

df["AuthorAffiliation"] = df["AuthorAffiliation"].astype(str)
df = df[df["AuthorAffiliation"].str.strip().ne("") & df["AuthorAffiliation"].ne("nan")]

# %%
df.shape
# Out:
# (3531, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3531 entries, 0 to 3876
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Conference              3531 non-null   object
#  1   Year                    3531 non-null   int64
#  2   Title                   3531 non-null   object
#  3   DOI                     3531 non-null   object
#  4   PaperType               3531 non-null   object
#  5   Abstract                3531 non-null   object
#  6   AuthorNames-Deduped     3531 non-null   object
#  7   AuthorAffiliation       3531 non-null   object
#  8   InternalReferences      3130 non-null   object
#  9   AuthorKeywords          2878 non-null   object
#  10  AminerCitationCount     3118 non-null   float64
#  11  CitationCount_CrossRef  3531 non-null   float64
#  12  PubsCited_CrossRef      3531 non-null   float64
#  13  Downloads_Xplore        3529 non-null   float64
# ...

# %%
df.to_csv("../data/processed/dataset_clean.csv", index=False, encoding="utf-8")
