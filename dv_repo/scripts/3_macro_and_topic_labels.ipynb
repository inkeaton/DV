# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
# --- Paths (match your project structure) ---
DATASET_CLEAN = Path("../data/processed/dataset_clean.csv")
MACRO_SUMMARY = Path("../data/processed/output/macro_summary.csv")
TOPIC_SUMMARY = Path("../data/processed/output/topic_summary_with_macros.csv") 
DATASET_WITH_CLUSTERS = Path("../data/processed/output/dataset_with_clusters_and_macros.csv")

for p in [DATASET_CLEAN, MACRO_SUMMARY, TOPIC_SUMMARY, DATASET_WITH_CLUSTERS]:
    assert p.exists(), f"Missing: {p}"

DATASET_CLEAN, MACRO_SUMMARY, TOPIC_SUMMARY, DATASET_WITH_CLUSTERS
# Out:
# (PosixPath('../data/processed/dataset_clean.csv'),
#  PosixPath('../data/processed/output/macro_summary.csv'),
#  PosixPath('../data/processed/output/topic_summary_with_macros.csv'),
#  PosixPath('../data/processed/output/dataset_with_clusters_and_macros.csv'))

# %%
# --- Load data ---
df_clean = pd.read_csv(DATASET_CLEAN, encoding="utf-8", encoding_errors="replace")
macro_summary = pd.read_csv(MACRO_SUMMARY, encoding="utf-8", encoding_errors="replace")
topic_summary = pd.read_csv(TOPIC_SUMMARY, encoding="utf-8", encoding_errors="replace")
df_all = pd.read_csv(DATASET_WITH_CLUSTERS, encoding="utf-8", encoding_errors="replace")

print("df_clean shape:", df_clean.shape)
print("macro_summary shape:", macro_summary.shape)
print("topic_summary shape:", topic_summary.shape)
print("df_all shape:", df_all.shape)

display(macro_summary.head())
display(topic_summary.head())
# Out:
# df_clean shape: (3530, 16)
# macro_summary shape: (10, 3)
# topic_summary shape: (29, 8)
# df_all shape: (3530, 21)
#    MacroId                                          MacroName  Count
# 0        2  Macro 2: meshes • triangulation • surface reco...   1716
# 1        3  Macro 3: flow field • flow fields • computatio...    459
# 2        4  Macro 4: infographics • visualisations • chart...    321
# 3        7  Macro 7: direct volume rendering • rendering v...    241
# 4        8  Macro 8: parallel coordinate plots • coordinat...    236
#    Topic  Count                                               Name  \
# 0      0    729  0_meshes_triangulation_surface reconstruction_...
# 1      1    366  1_flow field_flow fields_computational fluid d...
# 2      2    286                 2_causality_causal_chart_inference
# 3      3    186  3_parallel coordinate plots_coordinate plots_p...
# 4      4    139  4_deep neural networks_deep learning_deep neur...
#
#                                       Representation  \
# 0  ['meshes', 'triangulation', 'surface reconstru...
# 1  ['flow field', 'flow fields', 'computational f...
# 2  ['causality', 'causal', 'chart', 'inference', ...
# 3  ['parallel coordinate plots', 'coordinate plot...
# 4  ['deep neural networks', 'deep learning', 'dee...
#
#                                  Representative_Docs  \
# 0  ['New quadric metric for simplifying meshes wi...
# 1  ['UFAT-a particle tracer for time-dependent fl...
# 2  ['The Visual Causality Analyst: An Interactive...
# 3  ['Shape-preserving Star Coordinates . Dimensio...
# 4  ["Summit: Scaling Deep Learning Interpretabili...
#
#                                             Category  MacroId  \
# 0  meshes • triangulation • surface reconstructio...        2
# 1  flow field • flow fields • computational fluid...        3
# 2             causality • causal • chart • inference        2
# 3  parallel coordinate plots • coordinate plots •...        8
# 4  deep neural networks • deep learning • deep ne...        1
#
#                                            MacroName
# 0  Macro 2: meshes • triangulation • surface reco...
# 1  Macro 3: flow field • flow fields • computatio...
# 2  Macro 2: meshes • triangulation • surface reco...
# 3  Macro 8: parallel coordinate plots • coordinat...
# 4  Macro 1: deep neural networks • deep learning ...

# %%
# --- Macro short names + slugs (based on your MacroId/MacroName list) ---
MACRO_WEB = {
    0: {"MacroCategory": "Twitter & Social Media", "MacroSlug": "twitter-social-media"},
    1: {"MacroCategory": "Surgical Planning & Tomography", "MacroSlug": "surgical-planning-tomography"},
    2: {"MacroCategory": "Dimensionality Reduction & Multivariate Plots", "MacroSlug": "dimensionality-reduction-multivariate"},
    3: {"MacroCategory": "Meshes & Volume Rendering", "MacroSlug": "meshes-volume-rendering"},
    4: {"MacroCategory": "Flow Fields & CFD Visualization", "MacroSlug": "flow-fields-cfd"},
    5: {"MacroCategory": "Dashboards & Infographics", "MacroSlug": "dashboards-infographics"},
    6: {"MacroCategory": "VIS Literature & Bibliometrics", "MacroSlug": "vis-literature-bibliometrics"},
    7: {"MacroCategory": "Diffusion MRI & Tractography", "MacroSlug": "diffusion-mri-tractography"},
    8: {"MacroCategory": "Time Series & Temporal Patterns", "MacroSlug": "time-series-temporal-patterns"},
    9: {"MacroCategory": "Ultrasound Volume Rendering & Segmentation", "MacroSlug": "ultrasound-volume-rendering-segmentation"},
}

missing = sorted(set(range(10)) - set(MACRO_WEB.keys()))
assert not missing, f"Missing macro ids in mapping: {missing}"

MACRO_WEB
# Out:
# {0: {'MacroCategory': 'Twitter & Social Media',
#   'MacroSlug': 'twitter-social-media'},
#  1: {'MacroCategory': 'Surgical Planning & Tomography',
#   'MacroSlug': 'surgical-planning-tomography'},
#  2: {'MacroCategory': 'Dimensionality Reduction & Multivariate Plots',
#   'MacroSlug': 'dimensionality-reduction-multivariate'},
#  3: {'MacroCategory': 'Meshes & Volume Rendering',
#   'MacroSlug': 'meshes-volume-rendering'},
#  4: {'MacroCategory': 'Flow Fields & CFD Visualization',
#   'MacroSlug': 'flow-fields-cfd'},
#  5: {'MacroCategory': 'Dashboards & Infographics',
#   'MacroSlug': 'dashboards-infographics'},
#  6: {'MacroCategory': 'VIS Literature & Bibliometrics',
#   'MacroSlug': 'vis-literature-bibliometrics'},
#  7: {'MacroCategory': 'Diffusion MRI & Tractography',
#   'MacroSlug': 'diffusion-mri-tractography'},
#  8: {'MacroCategory': 'Time Series & Temporal Patterns',
#   'MacroSlug': 'time-series-temporal-patterns'},
#  9: {'MacroCategory': 'Ultrasound Volume Rendering & Segmentation',
#   'MacroSlug': 'ultrasound-volume-rendering-segmentation'}}

# %%
# --- Topic/Category short names + slugs (based on your CATEGORY table) ---
# Keys are Topic ids (0..29). Slugs are safe for URLs; CategoryFileSlug is safe for filenames.
TOPIC_WEB = {
    0: {"CategoryShort": "Mesh Simplification & Surface Reconstruction", "CategorySlug": "mesh-simplification-surface-reconstruction", "CategoryFileSlug": "t00-mesh-simplification"},
    1: {"CategoryShort": "Direct Volume Rendering & Ray Casting", "CategorySlug": "direct-volume-rendering-ray-casting", "CategoryFileSlug": "t01-direct-volume-rendering"},
    2: {"CategoryShort": "Flow Fields & Vortices (CFD)", "CategorySlug": "flow-fields-vortices-cfd", "CategoryFileSlug": "t02-flow-fields-vortices"},
    3: {"CategoryShort": "Dimensionality Reduction & Scatterplots", "CategorySlug": "dimensionality-reduction-scatterplots", "CategoryFileSlug": "t03-dimensionality-reduction"},
    4: {"CategoryShort": "Surgical Planning & Tomography", "CategorySlug": "surgical-planning-tomography", "CategoryFileSlug": "t04-surgical-planning"},
    5: {"CategoryShort": "Multi-Projector & High-Res Displays", "CategorySlug": "multi-projector-highres-displays", "CategoryFileSlug": "t05-multi-projector-displays"},
    6: {"CategoryShort": "Computational Topology & Contour Trees", "CategorySlug": "computational-topology-contour-trees", "CategoryFileSlug": "t06-contour-trees-topology"},
    7: {"CategoryShort": "Molecular Volume Rendering", "CategorySlug": "molecular-volume-rendering", "CategoryFileSlug": "t07-molecular-volume-rendering"},
    8: {"CategoryShort": "Diffusion MRI & Tractography", "CategorySlug": "diffusion-mri-tractography", "CategoryFileSlug": "t08-diffusion-mri"},
    9: {"CategoryShort": "Weather Forecast Visualization", "CategorySlug": "weather-forecast-visualization", "CategoryFileSlug": "t09-weather-forecast"},
    10: {"CategoryShort": "Sensemaking & Provenance", "CategorySlug": "sensemaking-provenance", "CategoryFileSlug": "t10-sensemaking-provenance"},
    11: {"CategoryShort": "Twitter & Social Media", "CategorySlug": "twitter-social-media", "CategoryFileSlug": "t11-twitter-social"},
    12: {"CategoryShort": "Unstructured Tetrahedral Volume Rendering", "CategorySlug": "unstructured-tetrahedral-volume-rendering", "CategoryFileSlug": "t12-tetrahedral-volume-rendering"},
    13: {"CategoryShort": "Sports Pattern Mining", "CategorySlug": "sports-pattern-mining", "CategoryFileSlug": "t13-sports-pattern-mining"},
    14: {"CategoryShort": "NLP & Question Answering", "CategorySlug": "nlp-question-answering", "CategoryFileSlug": "t14-nlp-question-answering"},
    15: {"CategoryShort": "IEEE VIS Bibliometrics", "CategorySlug": "ieee-vis-bibliometrics", "CategoryFileSlug": "t15-ieee-vis-bibliometrics"},
    16: {"CategoryShort": "Treemaps & Tree Layouts", "CategorySlug": "treemaps-tree-layouts", "CategoryFileSlug": "t16-treemaps"},
    17: {"CategoryShort": "Immersive Analytics (AR/VR)", "CategorySlug": "immersive-analytics-ar-vr", "CategoryFileSlug": "t17-immersive-analytics"},
    18: {"CategoryShort": "Dashboards & Infographics", "CategorySlug": "dashboards-infographics", "CategoryFileSlug": "t18-dashboards-infographics"},
    19: {"CategoryShort": "Colormaps & Color Perception", "CategorySlug": "colormaps-color-perception", "CategoryFileSlug": "t19-colormaps"},
    20: {"CategoryShort": "Eye Tracking & Gaze Analysis", "CategorySlug": "eye-tracking-gaze-analysis", "CategoryFileSlug": "t20-eye-tracking"},
    21: {"CategoryShort": "Tensor Field Topology", "CategorySlug": "tensor-field-topology", "CategoryFileSlug": "t21-tensor-fields"},
    22: {"CategoryShort": "Line Charts & Temporal Patterns", "CategorySlug": "line-charts-temporal-patterns", "CategoryFileSlug": "t22-line-charts"},
    23: {"CategoryShort": "Gene Expression & Genomics", "CategorySlug": "gene-expression-genomics", "CategoryFileSlug": "t23-gene-expression"},
    24: {"CategoryShort": "Visualization Design & Perception", "CategorySlug": "visualization-design-perception", "CategoryFileSlug": "t24-viz-design"},
    25: {"CategoryShort": "Narrative Visualization & Storytelling", "CategorySlug": "narrative-visualization-storytelling", "CategoryFileSlug": "t25-narrative-viz"},
    26: {"CategoryShort": "Cell Imaging & Machine Learning", "CategorySlug": "cell-imaging-machine-learning", "CategoryFileSlug": "t26-cell-imaging-ml"},
    27: {"CategoryShort": "Financial Monitoring & Anomaly Detection", "CategorySlug": "financial-monitoring-anomaly-detection", "CategoryFileSlug": "t27-financial-monitoring"},
    28: {"CategoryShort": "Illustrative Volume Rendering", "CategorySlug": "illustrative-volume-rendering", "CategoryFileSlug": "t28-illustrative-rendering"},
    29: {"CategoryShort": "Ultrasound Volume Rendering", "CategorySlug": "ultrasound-volume-rendering", "CategoryFileSlug": "t29-ultrasound"},
}

# If TOPIC_SUMMARY contains a Topic column, sanity-check coverage:
if "Topic" in topic_summary.columns:
    topics = sorted(pd.unique(topic_summary["Topic"].dropna().astype(int)))
    missing_topics = [t for t in topics if t not in TOPIC_WEB]
    if missing_topics:
        print("WARNING: Unmapped Topic id(s):", missing_topics)
    else:
        print("All topic ids in topic_summary are mapped:", len(topics))

TOPIC_WEB
# Out:
# All topic ids in topic_summary are mapped: 29
# {0: {'CategoryShort': 'Mesh Simplification & Surface Reconstruction',
#   'CategorySlug': 'mesh-simplification-surface-reconstruction',
#   'CategoryFileSlug': 't00-mesh-simplification'},
#  1: {'CategoryShort': 'Direct Volume Rendering & Ray Casting',
#   'CategorySlug': 'direct-volume-rendering-ray-casting',
#   'CategoryFileSlug': 't01-direct-volume-rendering'},
#  2: {'CategoryShort': 'Flow Fields & Vortices (CFD)',
#   'CategorySlug': 'flow-fields-vortices-cfd',
#   'CategoryFileSlug': 't02-flow-fields-vortices'},
#  3: {'CategoryShort': 'Dimensionality Reduction & Scatterplots',
#   'CategorySlug': 'dimensionality-reduction-scatterplots',
#   'CategoryFileSlug': 't03-dimensionality-reduction'},
#  4: {'CategoryShort': 'Surgical Planning & Tomography',
#   'CategorySlug': 'surgical-planning-tomography',
#   'CategoryFileSlug': 't04-surgical-planning'},
#  5: {'CategoryShort': 'Multi-Projector & High-Res Displays',
#   'CategorySlug': 'multi-projector-highres-displays',
#   'CategoryFileSlug': 't05-multi-projector-displays'},
#  6: {'CategoryShort': 'Computational Topology & Contour Trees',
#   'CategorySlug': 'computational-topology-contour-trees',
#   'CategoryFileSlug': 't06-contour-trees-topology'},
#  7: {'CategoryShort': 'Molecular Volume Rendering',
#   'CategorySlug': 'molecular-volume-rendering',
#   'CategoryFileSlug': 't07-molecular-volume-rendering'},
#  8: {'CategoryShort': 'Diffusion MRI & Tractography',
#   'CategorySlug': 'diffusion-mri-tractography',
#   'CategoryFileSlug': 't08-diffusion-mri'},
#  9: {'CategoryShort': 'Weather Forecast Visualization',
#   'CategorySlug': 'weather-forecast-visualization',
#   'CategoryFileSlug': 't09-weather-forecast'},
#  10: {'CategoryShort': 'Sensemaking & Provenance',
#   'CategorySlug': 'sensemaking-provenance',
#   'CategoryFileSlug': 't10-sensemaking-provenance'},
#  11: {'CategoryShort': 'Twitter & Social Media',
#   'CategorySlug': 'twitter-social-media',
#   'CategoryFileSlug': 't11-twitter-social'},
#  12: {'CategoryShort': 'Unstructured Tetrahedral Volume Rendering',
#   'CategorySlug': 'unstructured-tetrahedral-volume-rendering',
#   'CategoryFileSlug': 't12-tetrahedral-volume-rendering'},
#  13: {'CategoryShort': 'Sports Pattern Mining',
#   'CategorySlug': 'sports-pattern-mining',
#   'CategoryFileSlug': 't13-sports-pattern-mining'},
#  14: {'CategoryShort': 'NLP & Question Answering',
#   'CategorySlug': 'nlp-question-answering',
#   'CategoryFileSlug': 't14-nlp-question-answering'},
#  15: {'CategoryShort': 'IEEE VIS Bibliometrics',
#   'CategorySlug': 'ieee-vis-bibliometrics',
#   'CategoryFileSlug': 't15-ieee-vis-bibliometrics'},
#  16: {'CategoryShort': 'Treemaps & Tree Layouts',
#   'CategorySlug': 'treemaps-tree-layouts',
#   'CategoryFileSlug': 't16-treemaps'},
#  17: {'CategoryShort': 'Immersive Analytics (AR/VR)',
#   'CategorySlug': 'immersive-analytics-ar-vr',
#   'CategoryFileSlug': 't17-immersive-analytics'},
#  18: {'CategoryShort': 'Dashboards & Infographics',
#   'CategorySlug': 'dashboards-infographics',
#   'CategoryFileSlug': 't18-dashboards-infographics'},
#  19: {'CategoryShort': 'Colormaps & Color Perception',
#   'CategorySlug': 'colormaps-color-perception',
#   'CategoryFileSlug': 't19-colormaps'},
#  20: {'CategoryShort': 'Eye Tracking & Gaze Analysis',
#   'CategorySlug': 'eye-tracking-gaze-analysis',
#   'CategoryFileSlug': 't20-eye-tracking'},
#  21: {'CategoryShort': 'Tensor Field Topology',
#   'CategorySlug': 'tensor-field-topology',
#   'CategoryFileSlug': 't21-tensor-fields'},
#  22: {'CategoryShort': 'Line Charts & Temporal Patterns',
#   'CategorySlug': 'line-charts-temporal-patterns',
#   'CategoryFileSlug': 't22-line-charts'},
#  23: {'CategoryShort': 'Gene Expression & Genomics',
#   'CategorySlug': 'gene-expression-genomics',
#   'CategoryFileSlug': 't23-gene-expression'},
#  24: {'CategoryShort': 'Visualization Design & Perception',
#   'CategorySlug': 'visualization-design-perception',
#   'CategoryFileSlug': 't24-viz-design'},
#  25: {'CategoryShort': 'Narrative Visualization & Storytelling',
#   'CategorySlug': 'narrative-visualization-storytelling',
#   'CategoryFileSlug': 't25-narrative-viz'},
#  26: {'CategoryShort': 'Cell Imaging & Machine Learning',
#   'CategorySlug': 'cell-imaging-machine-learning',
#   'CategoryFileSlug': 't26-cell-imaging-ml'},
#  27: {'CategoryShort': 'Financial Monitoring & Anomaly Detection',
#   'CategorySlug': 'financial-monitoring-anomaly-detection',
#   'CategoryFileSlug': 't27-financial-monitoring'},
#  28: {'CategoryShort': 'Illustrative Volume Rendering',
#   'CategorySlug': 'illustrative-volume-rendering',
#   'CategoryFileSlug': 't28-illustrative-rendering'},
#  29: {'CategoryShort': 'Ultrasound Volume Rendering',
#   'CategorySlug': 'ultrasound-volume-rendering',
#   'CategoryFileSlug': 't29-ultrasound'}}

# %%
# --- Enrich + save macro_summary ---
macro_summary["MacroId"] = macro_summary["MacroId"].astype(int)

macro_summary["MacroCategory"] = macro_summary["MacroId"].map(lambda m: MACRO_WEB.get(m, {}).get("MacroCategory"))
macro_summary["MacroSlug"] = macro_summary["MacroId"].map(lambda m: MACRO_WEB.get(m, {}).get("MacroSlug"))

unmapped = macro_summary[macro_summary["MacroCategory"].isna()]["MacroId"].unique().tolist()
if unmapped:
    print("WARNING: Unmapped MacroId(s) in macro_summary:", unmapped)

macro_summary.to_csv(MACRO_SUMMARY, index=False)
print("Updated file written:", MACRO_SUMMARY.resolve())

display(macro_summary.head(20))
# Out:
# Updated file written: /Users/irynasavchuk/Desktop/DATAVIZ_PROJECT/DV/dv_repo/data/processed/output/macro_summary.csv
#    MacroId                                          MacroName  Count  \
# 0        2  Macro 2: meshes • triangulation • surface reco...   1716
# 1        3  Macro 3: flow field • flow fields • computatio...    459
# 2        4  Macro 4: infographics • visualisations • chart...    321
# 3        7  Macro 7: direct volume rendering • rendering v...    241
# 4        8  Macro 8: parallel coordinate plots • coordinat...    236
# 5        1  Macro 1: deep neural networks • deep learning ...    182
# 6        6  Macro 6: geophysical • geological • topography...    165
# 7        0  Macro 0: topological features • contour trees ...    111
# 8        5  Macro 5: wavelet • wavelets • multiresolution ...     52
# 9        9  Macro 9: anomaly detection • network security ...     47
#
#                                    MacroCategory  \
# 0  Dimensionality Reduction & Multivariate Plots
# 1                      Meshes & Volume Rendering
# 2                Flow Fields & CFD Visualization
# 3                   Diffusion MRI & Tractography
# 4                Time Series & Temporal Patterns
# 5                 Surgical Planning & Tomography
# 6                 VIS Literature & Bibliometrics
# 7                         Twitter & Social Media
# 8                      Dashboards & Infographics
# 9     Ultrasound Volume Rendering & Segmentation
#
#                                   MacroSlug
# 0     dimensionality-reduction-multivariate
# 1                   meshes-volume-rendering
# 2                           flow-fields-cfd
# 3                diffusion-mri-tractography
# 4             time-series-temporal-patterns
# 5              surgical-planning-tomography
# 6              vis-literature-bibliometrics
# 7                      twitter-social-media
# 8                   dashboards-infographics
# 9  ultrasound-volume-rendering-segmentation

# %%
# --- Enrich + save topic_summary ---
if "Topic" in topic_summary.columns:
    topic_summary["Topic"] = topic_summary["Topic"].astype(int)
    topic_summary["CategoryShort"] = topic_summary["Topic"].map(lambda t: TOPIC_WEB.get(t, {}).get("CategoryShort"))
    topic_summary["CategorySlug"] = topic_summary["Topic"].map(lambda t: TOPIC_WEB.get(t, {}).get("CategorySlug"))
    topic_summary["CategoryFileSlug"] = topic_summary["Topic"].map(lambda t: TOPIC_WEB.get(t, {}).get("CategoryFileSlug"))

    # Also bring MacroCategory/MacroSlug onto the topic table, if MacroId exists there
    if "MacroId" in topic_summary.columns:
        topic_summary["MacroId"] = topic_summary["MacroId"].astype(int)
        topic_summary["MacroCategory"] = topic_summary["MacroId"].map(lambda m: MACRO_WEB.get(m, {}).get("MacroCategory"))
        topic_summary["MacroSlug"] = topic_summary["MacroId"].map(lambda m: MACRO_WEB.get(m, {}).get("MacroSlug"))

    unmapped_topics = topic_summary[topic_summary["CategoryShort"].isna()]["Topic"].unique().tolist()
    if unmapped_topics:
        print("WARNING: Unmapped Topic(s) in topic_summary:", unmapped_topics)

    topic_summary.to_csv(TOPIC_SUMMARY, index=False)
    print("Updated file written:", TOPIC_SUMMARY.resolve())

display(topic_summary.head(30))
# Out:
# Updated file written: /Users/irynasavchuk/Desktop/DATAVIZ_PROJECT/DV/dv_repo/data/processed/output/topic_summary_with_macros.csv
#     Topic  Count                                               Name  \
# 0       0    729  0_meshes_triangulation_surface reconstruction_...
# 1       1    366  1_flow field_flow fields_computational fluid d...
# 2       2    286                 2_causality_causal_chart_inference
# 3       3    186  3_parallel coordinate plots_coordinate plots_p...
# 4       4    139  4_deep neural networks_deep learning_deep neur...
# 5       5    137             5_projector_calibration_camera_cameras
# 6       6    134  6_treemaps_treemap_volume exploration_volume i...
# 7       7    123  7_unstructured text_topic modeling_text mining...
# 8       8    114  8_simulation ensembles_parameter space explora...
# 9       9    113  9_direct volume rendering_ray tracing_unstruct...
# 10     10    111  10_topological features_contour trees_contour ...
# 11     11    110  11_molecular dynamics_molecular_molecules_mole...
# 12     12     93  12_haptic interface_haptic feedback_haptic_tac...
# 13     13     91  13_visualisations_infographics_sensemaking_abs...
# 14     14     71  14_interface exploration_database management_d...
# 15     15     70  15_immersive environments_augmented reality_vi...
# 16     16     62  16_geophysical_geological_topography_earth sci...
# 17     17     58  17_visualisation tools_computer graphics_compu...
# 18     18     57  18_volume illumination_volumetric shadows_dire...
# 19     19     54   19_blood vessels_blood flow_angiography_vascular
# 20     20     52  20_wavelet_wavelets_multiresolution_curvilinea...
# 21     21     51  21_tensor field topology_tensor fields_tensor ...
# 22     22     50  22_line charts_chart_temporal patterns_multiva...
# 23     23     50           23_sketching_infovis_literacy_creativity
# 24     24     50  24_diffusion tensor_magnetic resonance imaging...
# 25     25     47  25_anomaly detection_network security_network ...
# 26     26     45  26_eye tracking study_eye tracking_gaze_graphi...
# 27     27     43  27_driven storytelling_narratives_storytelling...
# 28     28     38  28_scientific literature_citations_bibliograph...
#
#                                        Representation  \
# 0   ['meshes', 'triangulation', 'surface reconstru...
# 1   ['flow field', 'flow fields', 'computational f...
# 2   ['causality', 'causal', 'chart', 'inference', ...
# 3   ['parallel coordinate plots', 'coordinate plot...
# 4   ['deep neural networks', 'deep learning', 'dee...
# 5   ['projector', 'calibration', 'camera', 'camera...
# 6   ['treemaps', 'treemap', 'volume exploration', ...
# 7   ['unstructured text', 'topic modeling', 'text ...
# 8   ['simulation ensembles', 'parameter space expl...
# 9   ['direct volume rendering', 'ray tracing', 'un...
# 10  ['topological features', 'contour trees', 'con...
# 11  ['molecular dynamics', 'molecular', 'molecules...
# 12  ['haptic interface', 'haptic feedback', 'hapti...
# 13  ['visualisations', 'infographics', 'sensemakin...
# 14  ['interface exploration', 'database management...
# 15  ['immersive environments', 'augmented reality'...
# 16  ['geophysical', 'geological', 'topography', 'e...
# 17  ['visualisation tools', 'computer graphics', '...
# 18  ['volume illumination', 'volumetric shadows', ...
# 19  ['blood vessels', 'blood flow', 'angiography',...
# 20  ['wavelet', 'wavelets', 'multiresolution', 'cu...
# 21  ['tensor field topology', 'tensor fields', 'te...
# 22  ['line charts', 'chart', 'temporal patterns', ...
# 23  ['sketching', 'infovis', 'literacy', 'creativi...
# 24  ['diffusion tensor', 'magnetic resonance imagi...
# 25  ['anomaly detection', 'network security', 'net...
# 26  ['eye tracking study', 'eye tracking', 'gaze',...
# 27  ['driven storytelling', 'narratives', 'storyte...
# 28  ['scientific literature', 'citations', 'biblio...
#
#                                   Representative_Docs  \
# 0   ['New quadric metric for simplifying meshes wi...
# 1   ['UFAT-a particle tracer for time-dependent fl...
# 2   ['The Visual Causality Analyst: An Interactive...
# 3   ['Shape-preserving Star Coordinates . Dimensio...
# 4   ["Summit: Scaling Deep Learning Interpretabili...
# 5   ['Auto-Calibration of Multi-Projector Displays...
# 6   ['Perceptual Guidelines for Creating Rectangul...
# 7   ["Elastic Documents: Coupling Text and Tables ...
# 8   ['Effective Visualization of Temporal Ensemble...
# 9   ['Fast Perspective Volume Rendering with Splat...
# 10  ['Efficient Computation of Morse-Smale Complex...
# 11  ['Characterizing Molecular Interactions in Che...
# 12  ['Immersive design of DNA molecules with a tan...
# 13  ["Measuring Effects of Spatial Visualization a...
# 14  ['PanoramicData: Data Analysis through Pen & T...
# 15  ['Design Patterns for Situated Visualization i...
# 16  ["SeiVis: An Interactive Visual Subsurface Mod...
# 17  ['Diderot: a Domain-Specific Language for Port...
# 18  ['About the Influence of Illumination Models o...
# 19  ['Combined Visualization of Vessel Deformation...
# 20  ['Wavelets applied to lossless compression and...
# 21  ['Global Topology of 3D Symmetric Tensor Field...
# 22  ['Visualization and Exploration of Temporal Tr...
# 23  ['Visualization Design Practices in a Crisis: ...
# 24  ['Case study: reconstruction, visualization an...
# 25  ['The State of the Art in BGP Visualization To...
# 26  ["Visual Analytics Methodology for Eye Movemen...
# 27  ["A Design Space for Applying the Freytag's Py...
# 28  ['Gender in 30 Years of IEEE Visualization . W...
#
#                                              Category  MacroId  \
# 0   meshes • triangulation • surface reconstructio...        2
# 1   flow field • flow fields • computational fluid...        3
# 2              causality • causal • chart • inference        2
# 3   parallel coordinate plots • coordinate plots •...        8
# 4   deep neural networks • deep learning • deep ne...        1
# 5          projector • calibration • camera • cameras        2
# 6   treemaps • treemap • volume exploration • volu...        7
# 7   unstructured text • topic modeling • text mini...        2
# 8   simulation ensembles • parameter space explora...        2
# 9   direct volume rendering • ray tracing • unstru...        2
# 10  topological features • contour trees • contour...        0
# 11  molecular dynamics • molecular • molecules • m...        4
# 12  haptic interface • haptic feedback • haptic • ...        3
# 13  visualisations • infographics • sensemaking • ...        4
# 14  interface exploration • database management • ...        2
# 15  immersive environments • augmented reality • v...        4
# 16  geophysical • geological • topography • earth ...        6
# 17  visualisation tools • computer graphics • comp...        6
# 18  volume illumination • volumetric shadows • dir...        7
# 19  blood vessels • blood flow • angiography • vas...        2
# 20  wavelet • wavelets • multiresolution • curvili...        5
# 21  tensor field topology • tensor fields • tensor...        2
# 22  line charts • chart • temporal patterns • mult...        4
# 23        sketching • infovis • literacy • creativity        8
# 24  diffusion tensor • magnetic resonance imaging ...        7
# 25  anomaly detection • network security • network...        9
# 26  eye tracking study • eye tracking • gaze • gra...        6
# 27  driven storytelling • narratives • storytellin...        1
# 28  scientific literature • citations • bibliograp...        2
#
#                                             MacroName  \
# 0   Macro 2: meshes • triangulation • surface reco...
# 1   Macro 3: flow field • flow fields • computatio...
# 2   Macro 2: meshes • triangulation • surface reco...
# 3   Macro 8: parallel coordinate plots • coordinat...
# 4   Macro 1: deep neural networks • deep learning ...
# 5   Macro 2: meshes • triangulation • surface reco...
# 6   Macro 7: direct volume rendering • rendering v...
# 7   Macro 2: meshes • triangulation • surface reco...
# 8   Macro 2: meshes • triangulation • surface reco...
# 9   Macro 2: meshes • triangulation • surface reco...
# 10  Macro 0: topological features • contour trees ...
# 11  Macro 4: infographics • visualisations • chart...
# 12  Macro 3: flow field • flow fields • computatio...
# 13  Macro 4: infographics • visualisations • chart...
# 14  Macro 2: meshes • triangulation • surface reco...
# 15  Macro 4: infographics • visualisations • chart...
# 16  Macro 6: geophysical • geological • topography...
# 17  Macro 6: geophysical • geological • topography...
# 18  Macro 7: direct volume rendering • rendering v...
# 19  Macro 2: meshes • triangulation • surface reco...
# 20  Macro 5: wavelet • wavelets • multiresolution ...
# 21  Macro 2: meshes • triangulation • surface reco...
# 22  Macro 4: infographics • visualisations • chart...
# 23  Macro 8: parallel coordinate plots • coordinat...
# 24  Macro 7: direct volume rendering • rendering v...
# 25  Macro 9: anomaly detection • network security ...
# 26  Macro 6: geophysical • geological • topography...
# 27  Macro 1: deep neural networks • deep learning ...
# 28  Macro 2: meshes • triangulation • surface reco...
#
#                                    CategoryShort  \
# 0   Mesh Simplification & Surface Reconstruction
# 1          Direct Volume Rendering & Ray Casting
# 2                   Flow Fields & Vortices (CFD)
# 3        Dimensionality Reduction & Scatterplots
# 4                 Surgical Planning & Tomography
# 5            Multi-Projector & High-Res Displays
# 6         Computational Topology & Contour Trees
# 7                     Molecular Volume Rendering
# 8                   Diffusion MRI & Tractography
# 9                 Weather Forecast Visualization
# 10                      Sensemaking & Provenance
# 11                        Twitter & Social Media
# 12     Unstructured Tetrahedral Volume Rendering
# 13                         Sports Pattern Mining
# 14                      NLP & Question Answering
# 15                        IEEE VIS Bibliometrics
# 16                       Treemaps & Tree Layouts
# 17                   Immersive Analytics (AR/VR)
# 18                     Dashboards & Infographics
# 19                  Colormaps & Color Perception
# 20                  Eye Tracking & Gaze Analysis
# 21                         Tensor Field Topology
# 22               Line Charts & Temporal Patterns
# 23                    Gene Expression & Genomics
# 24             Visualization Design & Perception
# 25        Narrative Visualization & Storytelling
# 26               Cell Imaging & Machine Learning
# 27      Financial Monitoring & Anomaly Detection
# 28                 Illustrative Volume Rendering
#
#                                   CategorySlug  \
# 0   mesh-simplification-surface-reconstruction
# 1          direct-volume-rendering-ray-casting
# 2                     flow-fields-vortices-cfd
# 3        dimensionality-reduction-scatterplots
# 4                 surgical-planning-tomography
# 5             multi-projector-highres-displays
# 6         computational-topology-contour-trees
# 7                   molecular-volume-rendering
# 8                   diffusion-mri-tractography
# 9               weather-forecast-visualization
# 10                      sensemaking-provenance
# 11                        twitter-social-media
# 12   unstructured-tetrahedral-volume-rendering
# 13                       sports-pattern-mining
# 14                      nlp-question-answering
# 15                      ieee-vis-bibliometrics
# 16                       treemaps-tree-layouts
# 17                   immersive-analytics-ar-vr
# 18                     dashboards-infographics
# 19                  colormaps-color-perception
# 20                  eye-tracking-gaze-analysis
# 21                       tensor-field-topology
# 22               line-charts-temporal-patterns
# 23                    gene-expression-genomics
# 24             visualization-design-perception
# 25        narrative-visualization-storytelling
# 26               cell-imaging-machine-learning
# 27      financial-monitoring-anomaly-detection
# 28               illustrative-volume-rendering
#
#                     CategoryFileSlug  \
# 0            t00-mesh-simplification
# 1        t01-direct-volume-rendering
# 2           t02-flow-fields-vortices
# 3       t03-dimensionality-reduction
# 4              t04-surgical-planning
# 5       t05-multi-projector-displays
# 6         t06-contour-trees-topology
# 7     t07-molecular-volume-rendering
# 8                  t08-diffusion-mri
# 9               t09-weather-forecast
# 10        t10-sensemaking-provenance
# 11                t11-twitter-social
# 12  t12-tetrahedral-volume-rendering
# 13         t13-sports-pattern-mining
# 14        t14-nlp-question-answering
# 15        t15-ieee-vis-bibliometrics
# 16                      t16-treemaps
# 17           t17-immersive-analytics
# 18       t18-dashboards-infographics
# 19                     t19-colormaps
# 20                  t20-eye-tracking
# 21                 t21-tensor-fields
# 22                   t22-line-charts
# 23               t23-gene-expression
# 24                    t24-viz-design
# 25                 t25-narrative-viz
# 26               t26-cell-imaging-ml
# 27          t27-financial-monitoring
# 28        t28-illustrative-rendering
#
#                                     MacroCategory  \
# 0   Dimensionality Reduction & Multivariate Plots
# 1                       Meshes & Volume Rendering
# 2   Dimensionality Reduction & Multivariate Plots
# 3                 Time Series & Temporal Patterns
# 4                  Surgical Planning & Tomography
# 5   Dimensionality Reduction & Multivariate Plots
# 6                    Diffusion MRI & Tractography
# 7   Dimensionality Reduction & Multivariate Plots
# 8   Dimensionality Reduction & Multivariate Plots
# 9   Dimensionality Reduction & Multivariate Plots
# 10                         Twitter & Social Media
# 11                Flow Fields & CFD Visualization
# 12                      Meshes & Volume Rendering
# 13                Flow Fields & CFD Visualization
# 14  Dimensionality Reduction & Multivariate Plots
# 15                Flow Fields & CFD Visualization
# 16                 VIS Literature & Bibliometrics
# 17                 VIS Literature & Bibliometrics
# 18                   Diffusion MRI & Tractography
# 19  Dimensionality Reduction & Multivariate Plots
# 20                      Dashboards & Infographics
# 21  Dimensionality Reduction & Multivariate Plots
# 22                Flow Fields & CFD Visualization
# 23                Time Series & Temporal Patterns
# 24                   Diffusion MRI & Tractography
# 25     Ultrasound Volume Rendering & Segmentation
# 26                 VIS Literature & Bibliometrics
# 27                 Surgical Planning & Tomography
# 28  Dimensionality Reduction & Multivariate Plots
#
#                                    MacroSlug
# 0      dimensionality-reduction-multivariate
# 1                    meshes-volume-rendering
# 2      dimensionality-reduction-multivariate
# 3              time-series-temporal-patterns
# 4               surgical-planning-tomography
# 5      dimensionality-reduction-multivariate
# 6                 diffusion-mri-tractography
# 7      dimensionality-reduction-multivariate
# 8      dimensionality-reduction-multivariate
# 9      dimensionality-reduction-multivariate
# 10                      twitter-social-media
# 11                           flow-fields-cfd
# 12                   meshes-volume-rendering
# 13                           flow-fields-cfd
# 14     dimensionality-reduction-multivariate
# 15                           flow-fields-cfd
# 16              vis-literature-bibliometrics
# 17              vis-literature-bibliometrics
# 18                diffusion-mri-tractography
# 19     dimensionality-reduction-multivariate
# 20                   dashboards-infographics
# 21     dimensionality-reduction-multivariate
# 22                           flow-fields-cfd
# 23             time-series-temporal-patterns
# 24                diffusion-mri-tractography
# 25  ultrasound-volume-rendering-segmentation
# 26              vis-literature-bibliometrics
# 27              surgical-planning-tomography
# 28     dimensionality-reduction-multivariate

# %%
# --- (Optional) write MacroCategory + Cluster (id) + ClusterShort (name) into dataset_clean.csv ---
# NOTE: In your pipeline, `topic_summary_with_macros.csv` uses column `Topic`,
# but `dataset_with_clusters_and_macros.csv` typically stores the same id in column `Cluster`.
# This block supports BOTH: it will use `Topic` if present, otherwise `Cluster`.

MERGE_KEY = "DOI"  # change if your join key is different

# Pick the column that contains the topic/cluster id
cluster_col = "Topic" if "Topic" in df_all.columns else ("Cluster" if "Cluster" in df_all.columns else None)
if cluster_col is None:
    raise ValueError("dataset_with_clusters_and_macros.csv is missing both 'Topic' and 'Cluster' columns.")

need_cols = [MERGE_KEY, "MacroId", cluster_col]
missing_cols = [c for c in need_cols if c not in df_all.columns]
if missing_cols:
    raise ValueError(f"dataset_with_clusters_and_macros.csv is missing columns: {missing_cols}")

# Build map + normalize name to `Cluster`
df_map = df_all[need_cols].copy().rename(columns={cluster_col: "Cluster"})

# Avoid exploding rows if there are duplicates in the merge key
if df_map[MERGE_KEY].duplicated().any():
    df_map = df_map.drop_duplicates(subset=[MERGE_KEY], keep="first")

df_out = df_clean.merge(df_map, on=MERGE_KEY, how="left")

# Macro labels
df_out["MacroCategory"] = df_out["MacroId"].map(
    lambda m: MACRO_WEB.get(int(m), {}).get("MacroCategory") if pd.notna(m) else np.nan
)
df_out["MacroSlug"] = df_out["MacroId"].map(
    lambda m: MACRO_WEB.get(int(m), {}).get("MacroSlug") if pd.notna(m) else np.nan
)

# Cluster/topic labels (short name)
df_out["ClusterShort"] = df_out["Cluster"].map(
    lambda t: TOPIC_WEB.get(int(t), {}).get("CategoryShort") if pd.notna(t) else np.nan
)
df_out["ClusterSlug"] = df_out["Cluster"].map(
    lambda t: TOPIC_WEB.get(int(t), {}).get("CategorySlug") if pd.notna(t) else np.nan
)
df_out["ClusterFileSlug"] = df_out["Cluster"].map(
    lambda t: TOPIC_WEB.get(int(t), {}).get("CategoryFileSlug") if pd.notna(t) else np.nan
)

# Report missing mappings
print("Rows with missing MacroCategory:", int(df_out["MacroCategory"].isna().sum()), "/", len(df_out))
print("Rows with missing ClusterShort:", int(df_out["ClusterShort"].isna().sum()), "/", len(df_out))

# Save
df_out.to_csv(DATASET_CLEAN, index=False)
print("Updated file written:", DATASET_CLEAN.resolve())

display(df_out.head())
# Out:
# Rows with missing MacroCategory: 0 / 3530
# Rows with missing ClusterShort: 0 / 3530
# Updated file written: /Users/irynasavchuk/Desktop/DATAVIZ_PROJECT/DV/dv_repo/data/processed/dataset_clean.csv
#   Conference  Year                                              Title  \
# 0        Vis  2024  Interactive Design-of-Experiments: Optimizing ...
# 1        Vis  2024  Towards Dataset-Scale and Feature-Oriented Eva...
# 2        Vis  2024  KNowNEt:Guided Health Information Seeking from...
# 3        Vis  2024  VisEval: A Benchmark for Data Visualization in...
# 4        Vis  2024  PUREsuggest: Citation-Based Literature Search ...
#
#                          DOI PaperType  \
# 0  10.1109/tvcg.2024.3456356         J
# 1  10.1109/tvcg.2024.3456398         J
# 2  10.1109/tvcg.2024.3456364         J
# 3  10.1109/tvcg.2024.3456320         J
# 4  10.1109/tvcg.2024.3456199         J
#
#                                             Abstract  \
# 0  The optimization of cooling systems is importa...
# 1  Recent advancements in Large Language Models (...
# 2  The increasing reliance on Large Language Mode...
# 3  Translating natural language to visualization ...
# 4  Citations allow quickly identifying related re...
#
#                                  AuthorNames-Deduped  \
# 0  Rainer Splechtna;Majid Behravan;Mario Jelovic;...
# 1  Sam Yu-Te Lee;Aryaman Bahukhandi;Dongyu Liu;Kw...
# 2  Youfu Yan;Yu Hou;Yongkang Xiao;Rui Zhang;Qianw...
# 3  Nan Chen;Yuge Zhang;Jiahang Xu;Kan Ren;Yuqing ...
# 4                                   Fabian Beck 0001
#
#                                    AuthorAffiliation  \
# 0  VRVis Research Center in Vienna, Austria;Virgi...
# 1  University of California, USA;University of Ca...
# 2  Department of Computer Science and Engineering...
# 3  Microsoft Research, USA;Microsoft Research, US...
# 4                     University of Bamberg, Germany
#
#                                   InternalReferences  \
# 0  10.1109/tvcg.2013.124;10.1109/tvcg.2008.145;10...
# 1  10.1109/tvcg.2017.2743858;10.1109/tvcg.2017.27...
# 2  10.1109/tvcg.2022.3209408;10.1109/tvcg.2023.33...
# 3  10.1109/infvis.2005.1532136;10.1109/tvcg.2015....
# 4  10.1109/tvcg.2015.2467757;10.1109/tvcg.2016.25...
#
#                                       AuthorKeywords  ...  Downloads_Xplore  \
# 0                        Parameter space exploration  ...             234.0
# 1  Visual analytics,prompt engineering,,,text sum...  ...             386.0
# 2  Human-AI interactions,knowledge graph,,,conver...  ...             632.0
# 3  Visualization evaluation,automatic visualizati...  ...             625.0
# 4  Scientific literature search,citation network ...  ...             165.0
#
#    Award  GraphicsReplicabilityStamp  MacroId Cluster  \
# 0    NaN                         NaN        2       8
# 1    NaN                         NaN        2       2
# 2     HM                         NaN        2       2
# 3     BP                         NaN        2       2
# 4    NaN                         NaN        2      28
#
#                                    MacroCategory  \
# 0  Dimensionality Reduction & Multivariate Plots
# 1  Dimensionality Reduction & Multivariate Plots
# 2  Dimensionality Reduction & Multivariate Plots
# 3  Dimensionality Reduction & Multivariate Plots
# 4  Dimensionality Reduction & Multivariate Plots
#
#                                MacroSlug                   ClusterShort  \
# 0  dimensionality-reduction-multivariate   Diffusion MRI & Tractography
# 1  dimensionality-reduction-multivariate   Flow Fields & Vortices (CFD)
# 2  dimensionality-reduction-multivariate   Flow Fields & Vortices (CFD)
# 3  dimensionality-reduction-multivariate   Flow Fields & Vortices (CFD)
# 4  dimensionality-reduction-multivariate  Illustrative Volume Rendering
#
#                      ClusterSlug             ClusterFileSlug
# 0     diffusion-mri-tractography           t08-diffusion-mri
# 1       flow-fields-vortices-cfd    t02-flow-fields-vortices
# 2       flow-fields-vortices-cfd    t02-flow-fields-vortices
# 3       flow-fields-vortices-cfd    t02-flow-fields-vortices
# 4  illustrative-volume-rendering  t28-illustrative-rendering
#
# [5 rows x 23 columns]
